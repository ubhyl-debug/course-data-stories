# %% [markdown]
# Deutsche Digitale Bibliothek REST API: https://labs.deutsche-digitale-bibliothek.de/app/ddbapi/#/search/getSolrSearch
#
# Fragen & Antworten zum Deutschen Zeitungsportal: https://www.deutsche-digitale-bibliothek.de/content/newspaper/fragen-antworten
#
# Wrapper for the DDB API: https://pypi.org/project/ddbapi/

# %% [markdown]
# # Functions for extracting and analyzing data from Das Deutsche Zeitungsportal:

# %%
import pandas as pd
from ddbapi import zp_pages
import folium
from geopy import geocoders

# %%
def article_extractor(search_dict):
    """
    This function extracts newspaper articles in a given language between two given dates. It takes a dictionary with 
    three keys as its only argument, like the following example:

    search_dict= {
        'language': 'ger',
        'date_begin': f'{year}-01-01',
        'date_end': f'{year}-12-31'
        }
    """
    
    df= zp_pages(language=search_dict['language'], 
                  publication_date= f"[{search_dict['date_begin']}T12:00:00Z TO {search_dict['date_end']}T12:00:00Z]")
    return df

# %% [markdown]
# Downloading newspaper data for each year in three chunks:

# %%
year_start = 1933
year_end = 1933
path= "./data_deutsches_zeitungsportal_misc"

# %%
search_dict= {
     'language': 'ger',
     'date_begin': f'{year_start}-01-01',
     'date_end': f'{year_end}-05-31'
     }
    
df_challenge= article_extractor(search_dict)
df_challenge
df_challenge.to_pickle(f"{path}/newspapers_{search_dict['language']}_{year_start}_part_1.pkl")
#df_challenge.to_parquet(
#    f"{path}/newspapers_{search_dict['language']}_{year_start}-{year_end}_part_1.parquet",
#    index=False,
#    compression='snappy'  # oder 'gzip' für stärkere Kompression
#)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 7
#       1 search_dict= {
#       2      'language': 'ger',
#       3      'date_begin': f'{year_start}-01-01',
#       4      'date_end': f'{year_end}-05-31'
#       5      }
# ----> 7 df_challenge= article_extractor(search_dict)
#       8 df_challenge
#       9 df_challenge.to_pickle(f"{path}/newspapers_{search_dict['language']}_{year_start}_part_1.pkl")
#
# Cell In[81], line 13, in article_extractor(search_dict)
#       1 def article_extractor(search_dict):
#       2     """
#       3     This function extracts newspaper articles in a given language between two given dates. It takes a dictionary with
#       4     three keys as its only argument, like the following example:
#    (...)
#      10         }
#      11     """
# ---> 13     df= zp_pages(language=search_dict['language'],
#      14                   publication_date= f"[{search_dict['date_begin']}T12:00:00Z TO {search_dict['date_end']}T12:00:00Z]")
#      15     return df
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\ddbapi\ddbapi.py:237, in zp_pages(**query)
#     235 # Gettin the data
#     236 try:
# --> 237     http.get(API_URL, params=params)
#     238 except Exception as e:
#     239     return e
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# search_dict= {
#     'language': 'ger',
#     'date_begin': f'{year}-05-01',
#     'date_end': f'{year}-08-31'
#     }
    
# df_challenge= article_extractor(search_dict)
# df_challenge.to_pickle(f"{path}/newspapers_{search_dict['language']}_{year}_part_2")

# %%
# search_dict= {
#     'language': 'ger',
#     'date_begin': f'{year}-09-01',
#     'date_end': f'{year}-12-31'
#     }
    
# df_challenge_ger= article_extractor(search_dict)
# df_challenge_ger.to_pickle(f"{path}/newspapers_{search_dict['language']}_{year}_part_3")

# %%
# # testing if the pickled dataframes are loadable: 

# test_year= f"{year}_part_3"
# columns= ['paper_title', 'publication_date', 'place_of_distribution']
# try:
#     print (len(pd.read_pickle(f"{path}/newspapers_{search_dict['language']}_{test_year}")[columns]))
                  
# except EOFError:
#     print(f"Error: EOFError occurred while loading data for year {test_year}.")

# %% [markdown]
# Downloading newspaper from 2023 for comparison in text quality

# %%
year_start = 1980
year_end = 1994
path= "./data_deutsches_zeitungsportal_misc"

# %%
search_dict= {
     'language': 'ger',
     'date_begin': f'{year_start}-01-01',
     'date_end': f'{year_end}-05-31'
     }
    
df_challenge= article_extractor(search_dict)
df_challenge
df_challenge.to_pickle(f"{path}/newspapers_{search_dict['language']}_{year_start}_part_1.pkl")
#df_challenge.to_parquet(
#    f"{path}/newspapers_{search_dict['language']}_{year_start}-{year_end}_part_1.parquet",
#    index=False,
#    compression='snappy'  # oder 'gzip' für stärkere Kompression
#)
df_challenge
# Out:
# https://api.deutsche-digitale-bibliothek.de/search/index/newspaper-issues/select?rows=1000&sort=id+ASC&q=type%3Apage+AND+language%3A%22ger%22+AND+publication_date%3A%22%5B1980-01-01T12%3A00%3A00Z%5C+TO%5C+1994-05-31T12%3A00%3A00Z%5D%22&cursorMark=%2A
# Getting 1000 of 2807
# Getting 2000 of 2807
# Getting 2807 of 2807
# Got 2807 items.
#                                                 page_id  pagenumber  \
# 0     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_001_DDB_...           1
# 1     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_002_DDB_...           2
# 2     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_003_DDB_...           3
# 3     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_004_DDB_...           4
# 4     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_005_DDB_...           5
# ...                                                 ...         ...
# 2802  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_004_DDB_...           4
# 2803  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_005_DDB_...           5
# 2804  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_006_DDB_...           6
# 2805  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_007_DDB_...           7
# 2806  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_008_DDB_...           8
#
#                                             paper_title  \
# 0     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 1     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 3     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 4     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# ...                                                 ...
# 2802  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2803  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2804  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2805  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2806  Der Motor : Zeitung der Dieselmotorenwerk Rost...
#
#                        provider_ddb_id                    provider     zdb_id  \
# 0     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 1     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 3     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 4     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# ...                                ...                         ...        ...
# 2802  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2803  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2804  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2805  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2806  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
#
#         publication_date place_of_distribution language  \
# 0    1980-03-11 12:00:00             [Rostock]    [ger]
# 1    1980-03-11 12:00:00             [Rostock]    [ger]
# 2    1980-03-11 12:00:00             [Rostock]    [ger]
# 3    1980-03-11 12:00:00             [Rostock]    [ger]
# 4    1980-03-11 12:00:00             [Rostock]    [ger]
# ...                  ...                   ...      ...
# 2802 1981-10-13 12:00:00             [Rostock]    [ger]
# 2803 1981-10-13 12:00:00             [Rostock]    [ger]
# 2804 1981-10-13 12:00:00             [Rostock]    [ger]
# 2805 1981-10-13 12:00:00             [Rostock]    [ger]
# 2806 1981-10-13 12:00:00             [Rostock]    [ger]
#
#                                  thumbnail  \
# 0     3c17273a-1495-4345-8bf5-df324f159dce
# 1     3c17273a-1495-4345-8bf5-df324f159dce
# 2     3c17273a-1495-4345-8bf5-df324f159dce
# 3     3c17273a-1495-4345-8bf5-df324f159dce
# 4     3c17273a-1495-4345-8bf5-df324f159dce
# ...                                    ...
# 2802  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2803  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2804  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2805  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2806  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
#
#                                            pagefulltext  \
# 0     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 1     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 2     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 3     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 4     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# ...                                                 ...
# 2802  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2803  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2804  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2805  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2806  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
#
#                    pagename  \
# 0     alto_001_DDB_FULLTEXT
# 1     alto_002_DDB_FULLTEXT
# 2     alto_003_DDB_FULLTEXT
# 3     alto_004_DDB_FULLTEXT
# 4     alto_005_DDB_FULLTEXT
# ...                     ...
# 2802  alto_004_DDB_FULLTEXT
# 2803  alto_005_DDB_FULLTEXT
# 2804  alto_006_DDB_FULLTEXT
# 2805  alto_007_DDB_FULLTEXT
# 2806  alto_008_DDB_FULLTEXT
#
#                                       preview_reference  \
# 0     https://api.deutsche-digitale-bibliothek.de/bi...
# 1     https://api.deutsche-digitale-bibliothek.de/bi...
# 2     https://api.deutsche-digitale-bibliothek.de/bi...
# 3     https://api.deutsche-digitale-bibliothek.de/bi...
# 4     https://api.deutsche-digitale-bibliothek.de/bi...
# ...                                                 ...
# 2802  https://api.deutsche-digitale-bibliothek.de/bi...
# 2803  https://api.deutsche-digitale-bibliothek.de/bi...
# 2804  https://api.deutsche-digitale-bibliothek.de/bi...
# 2805  https://api.deutsche-digitale-bibliothek.de/bi...
# 2806  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                       plainpagefulltext
# 0     = Organ der Parteileitung der SED im VEB Diese...
# 1     Am Arbeitsplatz mehr Vorsicht! 25 betriebliche...
# 2     Einer kennt ihn als Vertrauensmann, den Jugend...
# 3     der KDT und URANIA im DMR „MOTOR“ Leserausspra...
# 4     At ontage) heißt es so zügiger kann der a scho...
# ...                                                 ...
# 2802  |Ehrentafel Anlaßlich des 32, Jahrestages DDR ...
# 2803  icheren Händen ısatz und Disziplin ausgezeichn...
# 2804  SE NETTE ET TEE | | GELOBNIS % Wir, junge Bürg...
# 2805  port Am 28.September standen sich auf dem Lok-...
# 2806  Allerlei bunt gemischt Am Bildschirm miterlebe...
#
# [2807 rows x 14 columns]

# %% [markdown]
# # Perplexity
# In this part of the code, we attempt to derive perplexity using the 'distilgpt2' model. We calculate the perplexity for the column 'plainpagefulltext' for articles from 1933 and from 1980–1994, based on the assumption that the quality of the text improved with the transition from Old German to the modern alphabet. Because calculating perplexity for each row is computationally expensive, we generate a random sample consisting of 1.5% of the articles from 1933 and 20% of the articles from 1980–1994.
# ## 1933

# %%
df_1933 = pd.read_pickle("./data_deutsches_zeitungsportal_misc/newspapers_ger_1933_part_1.pkl")  
#read_in_df = pd.read_parquet("./data_deutsches_zeitungsportal_misc/newspapers_ger_1933_part_1.pkl")

# %%
df_1933
# Out:
#                                                   page_id  pagenumber  \
# 0       225ZVEUFAMVCRQLBYKG2WTI3WYTSORYZ-ALTO1541386_D...           1
# 1       225ZVEUFAMVCRQLBYKG2WTI3WYTSORYZ-ALTO1541387_D...           2
# 2       225ZVEUFAMVCRQLBYKG2WTI3WYTSORYZ-ALTO1541388_D...           3
# 3       225ZVEUFAMVCRQLBYKG2WTI3WYTSORYZ-ALTO1541389_D...           4
# 4       225ZVEUFAMVCRQLBYKG2WTI3WYTSORYZ-ALTO1541390_D...           5
# ...                                                   ...         ...
# 133379  ZZZZPIGJEYV3UWA7CW7RHXVDVJPRMXV5-uuid-a31b4e74...           2
# 133380  ZZZZPIGJEYV3UWA7CW7RHXVDVJPRMXV5-uuid-b889ea81...           6
# 133381  ZZZZPIGJEYV3UWA7CW7RHXVDVJPRMXV5-uuid-c11dedff...           3
# 133382  ZZZZPIGJEYV3UWA7CW7RHXVDVJPRMXV5-uuid-c5492995...           7
# 133383  ZZZZPIGJEYV3UWA7CW7RHXVDVJPRMXV5-uuid-ecb5632f...           5
#
#                                               paper_title  \
# 0                               Morgen-Zeitung. 1925-1949
# 1                               Morgen-Zeitung. 1925-1949
# 2                               Morgen-Zeitung. 1925-1949
# 3                               Morgen-Zeitung. 1925-1949
# 4                               Morgen-Zeitung. 1925-1949
# ...                                                   ...
# 133379  Weißeritz-Zeitung : Tageszeitung und Anzeiger ...
# 133380  Weißeritz-Zeitung : Tageszeitung und Anzeiger ...
# 133381  Weißeritz-Zeitung : Tageszeitung und Anzeiger ...
# 133382  Weißeritz-Zeitung : Tageszeitung und Anzeiger ...
# 133383  Weißeritz-Zeitung : Tageszeitung und Anzeiger ...
#
#                          provider_ddb_id  \
# 0       VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1       VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2       VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 3       VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 4       VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# ...                                  ...
# 133379  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 133380  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 133381  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 133382  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 133383  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
#
#                                                  provider     zdb_id  \
# 0       Universitäts- und Landesbibliothek der Rheinis...  2928805-8
# 1       Universitäts- und Landesbibliothek der Rheinis...  2928805-8
# 2       Universitäts- und Landesbibliothek der Rheinis...  2928805-8
# 3       Universitäts- und Landesbibliothek der Rheinis...  2928805-8
# 4       Universitäts- und Landesbibliothek der Rheinis...  2928805-8
# ...                                                   ...        ...
# 133379  Sächsische Landesbibliothek - Staats- und Univ...  3074708-9
# 133380  Sächsische Landesbibliothek - Staats- und Univ...  3074708-9
# 133381  Sächsische Landesbibliothek - Staats- und Univ...  3074708-9
# 133382  Sächsische Landesbibliothek - Staats- und Univ...  3074708-9
# 133383  Sächsische Landesbibliothek - Staats- und Univ...  3074708-9
#
#           publication_date                              place_of_distribution  \
# 0      1933-03-21 12:00:00  [Velbert, Neviges, Velbert-Langenberg, Wülfrat...
# 1      1933-03-21 12:00:00  [Velbert, Neviges, Velbert-Langenberg, Wülfrat...
# 2      1933-03-21 12:00:00  [Velbert, Neviges, Velbert-Langenberg, Wülfrat...
# 3      1933-03-21 12:00:00  [Velbert, Neviges, Velbert-Langenberg, Wülfrat...
# 4      1933-03-21 12:00:00  [Velbert, Neviges, Velbert-Langenberg, Wülfrat...
# ...                    ...                                                ...
# 133379 1933-01-31 12:00:00  [Dippoldiswalde, Frauenstein, Schmiedeberg (La...
# 133380 1933-01-31 12:00:00  [Dippoldiswalde, Frauenstein, Schmiedeberg (La...
# 133381 1933-01-31 12:00:00  [Dippoldiswalde, Frauenstein, Schmiedeberg (La...
# 133382 1933-01-31 12:00:00  [Dippoldiswalde, Frauenstein, Schmiedeberg (La...
# 133383 1933-01-31 12:00:00  [Dippoldiswalde, Frauenstein, Schmiedeberg (La...
#
#        language                             thumbnail  \
# 0         [ger]  26384eff-247a-4088-a290-d128d35fe611
# 1         [ger]  26384eff-247a-4088-a290-d128d35fe611
# 2         [ger]  26384eff-247a-4088-a290-d128d35fe611
# 3         [ger]  26384eff-247a-4088-a290-d128d35fe611
# 4         [ger]  26384eff-247a-4088-a290-d128d35fe611
# ...         ...                                   ...
# 133379    [ger]  fd1a6503-73b1-41c5-bacb-8442437bbd1e
# 133380    [ger]  fd1a6503-73b1-41c5-bacb-8442437bbd1e
# 133381    [ger]  fd1a6503-73b1-41c5-bacb-8442437bbd1e
# 133382    [ger]  fd1a6503-73b1-41c5-bacb-8442437bbd1e
# 133383    [ger]  fd1a6503-73b1-41c5-bacb-8442437bbd1e
#
#                                              pagefulltext  \
# 0       [/data/altos/22/5Z/225ZVEUFAMVCRQLBYKG2WTI3WYT...
# 1       [/data/altos/22/5Z/225ZVEUFAMVCRQLBYKG2WTI3WYT...
# 2       [/data/altos/22/5Z/225ZVEUFAMVCRQLBYKG2WTI3WYT...
# 3       [/data/altos/22/5Z/225ZVEUFAMVCRQLBYKG2WTI3WYT...
# 4       [/data/altos/22/5Z/225ZVEUFAMVCRQLBYKG2WTI3WYT...
# ...                                                   ...
# 133379  [/data/altos/ZZ/ZZ/ZZZZPIGJEYV3UWA7CW7RHXVDVJP...
# 133380  [/data/altos/ZZ/ZZ/ZZZZPIGJEYV3UWA7CW7RHXVDVJP...
# 133381  [/data/altos/ZZ/ZZ/ZZZZPIGJEYV3UWA7CW7RHXVDVJP...
# 133382  [/data/altos/ZZ/ZZ/ZZZZPIGJEYV3UWA7CW7RHXVDVJP...
# 133383  [/data/altos/ZZ/ZZ/ZZZZPIGJEYV3UWA7CW7RHXVDVJP...
#
#                                                  pagename  \
# 0                                ALTO1541386_DDB_FULLTEXT
# 1                                ALTO1541387_DDB_FULLTEXT
# 2                                ALTO1541388_DDB_FULLTEXT
# 3                                ALTO1541389_DDB_FULLTEXT
# 4                                ALTO1541390_DDB_FULLTEXT
# ...                                                   ...
# 133379  uuid-a31b4e74-67e9-4769-b4c4-48634ae29ddb_DDB_...
# 133380  uuid-b889ea81-49ef-4bbd-949a-c2df0134b796_DDB_...
# 133381  uuid-c11dedff-0487-48ef-aeec-7a40d95ab9c5_DDB_...
# 133382  uuid-c5492995-33ed-4c6f-8c84-cb12044e62f5_DDB_...
# 133383  uuid-ecb5632f-75f7-4e65-a6ed-acdce043e6da_DDB_...
#
#                                         preview_reference  \
# 0       https://api.deutsche-digitale-bibliothek.de/bi...
# 1       https://api.deutsche-digitale-bibliothek.de/bi...
# 2       https://api.deutsche-digitale-bibliothek.de/bi...
# 3       https://api.deutsche-digitale-bibliothek.de/bi...
# 4       https://api.deutsche-digitale-bibliothek.de/bi...
# ...                                                   ...
# 133379  https://api.deutsche-digitale-bibliothek.de/bi...
# 133380  https://api.deutsche-digitale-bibliothek.de/bi...
# 133381  https://api.deutsche-digitale-bibliothek.de/bi...
# 133382  https://api.deutsche-digitale-bibliothek.de/bi...
# 133383  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                         plainpagefulltext
# 0       Einzelnummer 15 Pig . Mit Ill . = Blatt 30 Pfg...
# 1       Dienstag , den 21 . März Morgen - Zeiltunh 193...
# 2       ine im wer arla damit lüssen eine ichs gexer 1...
# 3       Dienskag , de R O MAN von WERNER SCHEFF Inhalt...
# 4       Dienskag , den 21 . 1933 — Nummer 79 , Seite 9...
# ...                                                   ...
# 133379  Platz hinweg nach der Wilhelmstraße eilten, wo...
# 133380  Leutnant in Vas Insauterieregimen« Nr 73 (Hann...
# 133381  > Im übrigen bringe dieser Artikel eine Verdre...
# 133382  Aaveveui. Demonstrationsverb o t. Der SMj>, Ut...
# 133383  Beilage zur „Meißeritz -LeiL««s" Nr. 26 Dienst...
#
# [133384 rows x 14 columns]

# %%
unique_titles = df_1933["paper_title"].unique()

titles_df = pd.DataFrame(unique_titles, columns=["paper_title"])

titles_df.to_excel("unique_paper_titles.xlsx", index=False)

df_1933["paper_title"].unique()
# Out:
# array(['Morgen-Zeitung. 1925-1949', 'Deutsche Reichs-Zeitung. 1871-1934',
#        'Der Erft-Bote. 1890-1950',
#        'Dresdner Nachrichten, 02-Abendausgabe',
#        'Westfälische neueste Nachrichten mit Bielefelder General-Anzeiger und Handelsblatt',
#        'Neue Mannheimer Zeitung : NMZ : Mannheimer Neues Tageblatt, Abendblatt',
#        'Laupheimer Verkündiger : verbunden mit dem Laupheimer Volksblatt',
#        'Kölnische Zeitung. 1803-1945',
#        'Westfälische Zeitung : Bielefelder Tageblatt',
#        'Mittelbadischer Courier : Ettlinger Tagblatt ; mit den neuesten Handels-Nachrichten für Stadt und Bezirk Ettlingen',
#        'Erzgebirgischer Volksfreund : mit Schwarzenberger Tageblatt',
#        'Neckar-Bote : Heimatzeitung für Seckenheim und Umgebung',
#        'Iserlohner Kreisanzeiger und Zeitung. 1898-1949',
#        'Sächsische Dorfzeitung und Elbgaupresse : mit Loschwitzer Anzeiger ; Tageszeitung für das östliche Dresden u. seine Vororte',
#        'Hörder Volksblatt. 1884-1934',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Morgenausgabe',
#        'Echo des Siebengebirges. 1873-1941',
#        'Thomas a Kempis : Sonntagsblatt : Beilage zum Niederrheinischen Tageblatt',
#        'Deutscher Reichsanzeiger und Preußischer Staatsanzeiger',
#        'Der Rottumbote: amtliches und private Anzeigeblatt für Ochsenhausen und Umgebung',
#        'Karlsruher Zeitung', 'Bürener Zeitung. 1896-1935',
#        'Hildener Rundschau. 1924-1936',
#        'Arbeiterstimme  : Tageszeitung der Kommunistischen Partei Deutschlands, Sektion der Kommunistischen Internationale, Bezirk Sachsen, Verbreitungsgebiet Ostsachsen',
#        'Bergedorfer Zeitung : unabhängig, überparteilich ; mit amtl. Bekanntmachungen',
#        'Karlsruher Tagblatt, Frauenbeilage', 'Grenzwarte. 1927-1934',
#        'Vorwärts', 'Karlsruher Tagblatt', 'Dortmunder Zeitung. 1874-1939',
#        'Gießener Anzeiger : General-Anzeiger für Oberhessen, Frühausgabe',
#        'Hamburger Fremdenblatt, Reichsausgabe',
#        'Wittener Tageblatt : verbunden mit der Annener Zeitung',
#        'Viernheimer Anzeiger : Viernheimer Zeitung : Viernheimer Tageblatt : Viernheimer Nachrichten : Viernheimer Bürger-Ztg. : Viernh. Volksblatt',
#        'Stadtanzeiger für Castrop-Rauxel und Umgebung : Castroper Zeitung, Rauxeler Neueste Nachrichten, Bladenhorster Tageblatt : amtliches Veröffentlichungsblatt für den Landgerichtsbezirk Dortmund, allgemeindes Kreisblatt für den Stadtkreis Castrop-Rauxel',
#        'Der Landbote : Anzeiger für den Amtsbezirk Sinsheim und Umgebung',
#        'Marbacher Zeitung : Bottwartal-Bote',
#        'Gelsenkirchener allgemeine Zeitung. 1904-1943',
#        'Ahauser Kreiszeitung : amtliches Kreisblatt für den Landkreis Ahaus : Zentral-Organ für das nordwestliche Münsterland : verbunden mit Gronauer Volkszeitung',
#        'Buersche Volkszeitung. 1922-1933',
#        'Der Bote vom Geising und Müglitztal-Zeitung : Bezirksanzeiger für Altenberg, Geising, Lauenstein, Bärenstein und die umliegenden Ortschaften',
#        'Das blaue Heft : Theaterkunst, Politik, Wirtschaft',
#        'Süddeutsche Zeitung : für deutsche Politik und Volkswirtschaft',
#        'Jeversches Wochenblatt : Friesisches Tageblatt ; gegr. 1791',
#        'Recklinghäuser Volks-Zeitung : Heimatblatt für den Stadt- und Landkreis Recklinghausen',
#        'Kemberger Zeitung : vormals Generalanzeiger für Kemberg, Bad Schmiedeberg und Umgegend ; Amtsblatt für den Magistrat zu Kemberg, das Amtsgericht und verschiedene Gemeinden',
#        'Volksblatt für Harburg, Wilhelmsburg und Umgegend',
#        'Solinger Tageblatt : die Nachmittagszeitung der Klingenstadt : aelteste Tageszeitung im Stadtkreis Solingen',
#        'Dorstener Volkszeitung. 1919-1933', 'Bergische Post. 1924-1941',
#        'Westfälischer Beobachter : Bielefelder Beobachter : Herforder Beobachter : Mindener Beobachter : aelteste nationalsozialist. Zeitung für Westfalen-Nord',
#        'Rheinisches Volksblatt : Hildener Zeitung und Tageblatt : Hildener Rundschau',
#        'Lokal-Anzeiger für Stadt und Land. 1932-1934',
#        'Gießener Anzeiger : General-Anzeiger für Oberhessen, Erstes Blatt',
#        'Sozialdemokrat',
#        'Hakenkreuzbanner : NS-Tageszeitung für Mannheim u. Nordbaden',
#        'Central-Volksblatt für das gesamte Sauerland : Arnsberger Zeitung : Sauerländer Bote',
#        'Bergische Wacht. 1907-1941',
#        'Börsenblatt für den deutschen Buchhandel : bbb ; Fachzeitschr. für Verlagswesen u. Buchhandel',
#        'Ratinger Zeitung',
#        'Ohligser Anzeiger : Ohligser Zeitung und Tageblatt ; einzige in Ohligs erscheinende Tageszeitung',
#        'Eibenstocker Tageblatt : Anzeiger für den Amtsgerichtsbezirk Eibenstock und dessen Umgebung, umfassend die Ortschaften Eibenstock, Blauenthal, Carlsfeld, Hundshübel, Neuheide, Oberstützengrün, Schönheide, Schönheiderhammer, Sosa, Unterstützengrün, Wildenthal, Wilzschhaus, Wolfsgrün usw',
#        'Riesaer Tageblatt und Anzeiger : (Elbeblatt und Anzeiger) : amtliche Bekanntmachungen für die Stadt und den Landkreis Riesa',
#        'Langenberger Zeitung. 1888-1935',
#        'Hohenstein-Ernstthaler Tageblatt und Anzeiger : Hohenstein-Ernstthaler Zeitung, Nachrichten und Neueste Nachrichten ; Generalanzeiger für Hohenstein-Ernstthal mit Hüttengrund, Oberlungwitz, Gersdorf, Hermsdorf, Bernsdorf, ...',
#        'Merseburger Tageblatt : Kreisblatt ; mit den amtlichen Bekanntmachungen des Stadt- und Landkreises Merseburg',
#        'Duisburger General-Anzeiger. 1914-1935',
#        'Westdeutsche Landeszeitung : Gladbacher Volkszeitung und Handelsblatt : allgemeiner Anzeiger für den gesamten Niederrhein : die Niederrheinische Heimatzeitung',
#        'Lippspringer Anzeiger : nationale Tageszeitung für die Stadt Bad Lippspringe : Heimatzeitung für Jedermann : Publikationsorgan vieler Behörden',
#        'Neckar-Bote : Heimatzeitung für Seckenheim und Umgebung, Zweites Blatt',
#        'Sonntagsfriede',
#        'Schwäbischer Merkur ; [...] ; Wochenausgabe für das Ausland',
#        'Schwelmer Zeitung : allgemeiner Kreisanzeiger für den Ennepe-Ruhr-Kreis : Schwelmer Stadtanzeiger',
#        'Münsterischer Anzeiger : Westfälischer Merkur : Münsterische Volkszeitung : amtliches Organ des Gaues Westfalen-Nord der NSDAP und sämtlicher Behörden',
#        'Zwönitztaler Anzeiger',
#        'Saale-Zeitung : allgemeine Zeitung für Mitteldeutschland ; Hallesche neueste Nachrichten',
#        'Bochumer Anzeiger und General-Anzeiger. 1929-1934',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Abendausgabe',
#        'Dresdner Nachrichten',
#        'Weißeritz-Zeitung : Tageszeitung und Anzeiger für Dippoldiswalde, Schmiedeberg u. U.',
#        'Hamburger Volkszeitung : kommunistische Tageszeitung für Hamburg und Umgebung',
#        'Durlacher Tagblatt : Heimatblatt für die Stadt und den früheren Amtsbezirk Durlach; Pfinztäler Bote für Grötzingen, Berghausen, Söllingen, Wöschbach u. Kleinsteinbach',
#        'Sächsische Elbzeitung : Tageblatt für die Sächsische Schweiz',
#        'Wochenblatt für Zschopau und Umgegend : Zschopauer Tageblatt u. Anzeiger',
#        'NS-Kurier : Südwestdeutsche Tageszeitung für Politik, Wirtschaft, Kultur : Amtsblatt für Stadt und Amtsoberamt Stuttgart',
#        'Rheinisches Volksblatt',
#        'Der sächsische Erzähler : Bischofswerdaer Tageblatt ; (Tageblatt für Bischofswerda, Neukirch und Umgebung)',
#        'General-Anzeiger. 1889-1945',
#        'Rheinisch-Bergische Zeitung : Heidersche Zeitung ; ältestes Blatt des Rheinisch-Bergischen Kreises',
#        'Bergische Zeitung. 1922-1935', 'Dresdner neueste Nachrichten',
#        'Volkswille : Organ der sozialdemokratischen Partei : Publikationsorgan der freien Gewerkschaften und der Arbeitersportvereine',
#        'Godesberger Volkszeitung. 1913-1933',
#        'Bergheimer Zeitung. 1905-1943',
#        'Hamburgischer Correspondent : Morgen-Zeitung d. Börsen-Halle, Morgenausgabe',
#        'Die Feierstunde. 1919-1939', 'MZ am Sonntag. 1931-1933',
#        'Gießener Anzeiger : General-Anzeiger für Oberhessen, Zweites Blatt',
#        'Volksblatt : Organ der Sozialdemokratischen Partei',
#        'Wilhelmsburger Zeitung : das Echo der Elbinsel : die Stimme deiner Heimat',
#        'Bonner Zeitung. 1895-1933',
#        'Rhein- und Ruhrzeitung : Tageszeitung für das niederrheinische Industriegebiet und den linken Niederrhein : das Blatt der westdeutschen Binnenschiffahrt',
#        'Wittener Volkswacht : Organ der werktätigen Bevölkerung für den Stadtkreis Witten ; Mitteilungsblatt der freien Gewerkschaften und der Arbeiter-, Sport- und Kulturvereine',
#        'Bünder Tageblatt. 1901-1942',
#        'Gießener Anzeiger : General-Anzeiger für Oberhessen',
#        'Erholungsstunden. 1933-1933',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Montagausgabe',
#        'Süderländer Tageblatt : Plettenberger Zeitung : Sauerländischer Beobachter : amtl. Anzeiger für Plettenberg-Stadt u. die Ämter Plettenberg u. Herscheid : älteste und meistgelesene Tageszeitung im Verbreitungsgebiet',
#        'Riedlinger Zeitung : Tag- und Anzeigeblatt für den Bezirk Riedlingen',
#        'Schwerter Zeitung : Heimatblatt für die Stadt Schwerte und die Ämter Westhofen und Ergste : einzige in Schwerte gedruckte Zeitung',
#        'Velberter Zeitung : Nevigeser Volkszeitung : Heiligenhauser Zeitung',
#        'Schwäbischer Merkur : mit Schwäbischer Kronik und Handelszeitung : Süddeutsche Zeitung',
#        'Münsterländische Volkszeitung : allgemeiner Anzeiger für Stadt u. Amt Rheine : Zeno-Zeitung ; [...] ; Rheiner Volksblatt',
#        'Neue Mannheimer Zeitung : NMZ : Mannheimer Neues Tageblatt, Sonntagsblatt',
#        'Sauerländisches Volksblatt : aeltester Anzeiger des Sauerlandes : ueber 100 Jahre Heimat- und Kreisblatt im Kreise Olpe : Tageszeitung für Politik, Unterhaltung und Belehrung',
#        'Haaner Zeitung. 1928-1941', 'Junge Front. 1932-1935',
#        'Echo der Gegenwart. 1848-1935',
#        'Aufwärts : christliches Tageblatt',
#        'Sächsische Volkszeitung : für christliche Politik und Kultur',
#        'Verbo Schussen-Bote : Oberschw. Morgenblatt',
#        'General-Anzeiger für Dortmund und das gesamte rheinisch-westfälische Industriegebiet. 1927-1933',
#        'Volksblatt : Lippische Zeitung, Detmold',
#        'Illustrierte Beilage Rheinischen Volksblatt. 1929-1936',
#        'Bottwartal-Bote : Amtsblatt für die Stadt Grossbottwar : Beilsteiner Zeitung, Mundelsheimer Nachrichten, Oberstenfelder Anzeiger',
#        'Kirchlich-positive Blätter : Wochenschr. für kirchl. Leben in Baden',
#        'Wittener Volks-Zeitung : verbunden mit dem "Wittener Lokal-Anzeiger"',
#        'Neue Mannheimer Zeitung : NMZ : Mannheimer Neues Tageblatt, Mittagsblatt',
#        'Durlacher Tagblatt : Heimatblatt für die Stadt und den früheren Amtsbezirk Durlach; Pfinztäler Bote für Grötzingen, Berghausen, Söllingen, Wöschbach u. Kleinsteinbach, Zweites Blatt',
#        'Volksblatt <Halle, Saale> : Tageszeitung der Sozialdemokratischen Partei Deutschlands für die Provinz Sachsen',
#        'Harburger Anzeigen und Nachrichten', 'Der Sonntag. 1927-1933',
#        'Hamburger Tageblatt : Zeitung der Nationalsozialistischen Deutschen Arbeiterpartei',
#        'Castrop-Rauxeler Volkszeitung : Stadtkreis Castrop-Rauxel',
#        'Das bunte Blatt. 1926-1933', 'Wittgensteiner Kreisblatt',
#        'Rheinisches Signal : Wochenzeitung für Politik und Unterhaltung',
#        'Die Glocke. 1885-1933',
#        'Billstedter Zeitung : Horner Zeitung ; Lokalanzeiger für Billstedt, Horn, Billbrook, Billwärder, Oststeinbek, Havighorst, Glinde, Lohbrügge u. Umgegend ; Heimatzeitung im Osten Hamburgs',
#        'Die Heimat', 'Gütersloher Volks-Zeitung. 1929-1933',
#        'Aachener Anzeiger : politisches Tageblatt : beliebtes und wirksames Anzeigenblatt der Stadt und der Regierungsbezirks',
#        'Badischer Beobachter : Hauptorgan der badischen Zentrumspartei',
#        'Mitteldeutsche Nationalzeitung',
#        'Niederrheinisches Tageblatt : Kempener Volkszeitung : Kempener Zeitung : Lobbericher Tageblatt : Heimatzeitung für den linken Niederrhein',
#        'Bergische Landes-Zeitung. 1931-1945',
#        'Leipziger jüdische Wochenschau',
#        'Hellweg-Märkisches Volksblatt. 1930-1933',
#        'Sauerlandia : Wochenblatt für Familie und Heimat : Beilage zur Tremonia-Central-Volksblatt',
#        'Honnefer Volkszeitung. 1889-1978', 'Der Grafschafter. 1914-1945',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 3',
#        'Karlsruher Tagblatt, Sonderbeilage. Zum bevorstehenden Wohnungswechsel!',
#        'Der Baumeister : Fachorgan des Badischen Baumeister-Bundes  umfassend die staatl. geprüften Bad. Baumeister des Hoch- und Tiefbaues, sowie der Maschinen- und Elektrotechnik, BBB',
#        'Der Abend. 1933-1933',
#        'Wanne-Eickeler Zeitung : allgemeine Zeitung : General-Anzeiger : Hertener Tageblatt',
#        'Biberacher Zeitung : Nationalsozialistische Zeitung für das mittlere Oberschwaben',
#        'Neue Mannheimer Zeitung : NMZ : Mannheimer Neues Tageblatt, Morgenblatt',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Bundschuh und Hakenkreuz',
#        'Dresdner Nachrichten, 01-Frühausgabe',
#        'Unterhaltungsblatt : Sonntags-Beilage der Gelsenkirchener Allgemeinen Zeitung',
#        'St. Nicolaus-Blatt',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der deutsche Mittelstand',
#        'Angebotene und gesuchte Bücher',
#        'Hallische Nachrichten : General-Anzeiger für Halle und die Provinz Sachsen',
#        'Oberkasseler Zeitung : Heimatzeitung für Oberkassel, Ober- und Niederdollendorf und Römlinghoven',
#        'Marienbote : Sonntagsblatt für katholische Volk : Kirchenblatt für das Dekanat Telgte',
#        'Evangelischer Gemeindebote Karlsruhe',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Sonntagausgabe',
#        'Norddeutsche Zeitung : Organ der KPD für die Werktätigen Norddeutschlands',
#        'Deutsches Land. 1926-1935',
#        'Volkswacht : Organ der Sozialdemokratie für das östl. Westfalen und die lippischen Freistaaten',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der Ratgeber',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine',
#        'Die Feierstunde. 1924-1933',
#        'Evangelisches Kirchen- und Volksblatt : Sonntagsblatt für Baden',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der junge Freiheitskämpfer',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der Arbeiter im Betrieb',
#        'Annener Zeitung : verbunden mit der Annener Volkszeitung : Anzeigenblatt für Witten-Annen und die Stadtteile Rüdinghausen, Stockum und Düren',
#        'Amtsverkündigungsblatt für die Provinzialdirektion Oberhessen und der Kreisämter Gießen, Friedberg, Büdingen, Lauterbach, Schotten und Alsfeld',
#        'Mittelbadischer Courier : Ettlinger Tagblatt ; mit den neuesten Handels-Nachrichten für Stadt und Bezirk Ettlingen, Illustriertes Unterhaltungsblatt',
#        'Durlacher Tagblatt : Heimatblatt für die Stadt und den früheren Amtsbezirk Durlach; Pfinztäler Bote für Grötzingen, Berghausen, Söllingen, Wöschbach u. Kleinsteinbach, Roman-Blatt',
#        'Bild-Kurier : Beilage zum Hannoverschen Kurier',
#        'Gemeindeblatt der Jüdischen Gemeinde zu Berlin : amtliches Organ des Gemeindevorstandes',
#        'Karlsruher Tagblatt, Neujahrsbeilage. Jahreswende',
#        'Korrespondenzblatt über Auswanderungs- und Siedlungswesen',
#        'Gesetzes- und Verordnungsblatt für die Vereinigte Evangelisch-Protestantische Landeskirche Badens',
#        'Durlacher Tagblatt : Heimatblatt für die Stadt und den früheren Amtsbezirk Durlach; Pfinztäler Bote für Grötzingen, Berghausen, Söllingen, Wöschbach u. Kleinsteinbach, Roman-Blatt. Beilage zum Durlacher Tageblatt',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Rasse und Volk',
#        'Der Erzähler. 1931-1933',
#        'Badische Feuerwehr-Zeitung : offizielles Organ d. Badischen Landes-Feuerwehr-Verbandes u. d. badischen Feuerwehren',
#        'Der Turm. 1920-1934',
#        'Riesaer Tageblatt und Anzeiger : (Elbeblatt und Anzeiger) : amtliche Bekanntmachungen für die Stadt und den Landkreis Riesa, 02-Sonderausgabe',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Osterausgabe',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 6',
#        'Merseburger Tageblatt : Kreisblatt ; mit den amtlichen Bekanntmachungen des Stadt- und Landkreises Merseburg, #',
#        'Ottendorfer Zeitung', 'Karlsruher Tagblatt, Literatur-Beilage',
#        'Hamburgischer Correspondent : Morgen-Zeitung d. Börsen-Halle, Abendausgabe',
#        'Der Rad- und Kraftfahrer : amtliches Organ für das Rad- u. Kraftfahrwesen des Sächsischen Radfahrer-Bundes e.V.',
#        'Rheinischer Erzähler : Unterhaltungsbeilage zum Rheinischen Volksblatt : Hildener Zeitung und Tageblatt',
#        'Die Heimat. 1921-1944', 'Feierabend',
#        'Karlsruher Tagblatt, Sport Turnen Spiel',
#        'Internationale Literatur', 'Die Hochwarte. 1929-1935',
#        'Der Sonntag. 1922-1933',
#        'Karlsruher Zeitung, Badische Kultur und Geschichte Nr. 11',
#        'Kemberger Zeitung : vormals Generalanzeiger für Kemberg, Bad Schmiedeberg und Umgegend ; Amtsblatt für den Magistrat zu Kemberg, das Amtsgericht und verschiedene Gemeinden, 1 Blatt nicht vorhanden; Kein Datum in der Ausgabe. Das tatsächliche Datum ist ermittelt.',
#        'Karlsruher Tagblatt, Wandern und Reisen',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine, Sonderdruck zur "Badischen Schulzeitung" Nr.6',
#        'Ratgeber für Landwirte', 'Kirchlich-positive Blätter für Baden',
#        'Heimat-Blätter. 1925-1938',
#        'Durlacher Tagblatt : Heimatblatt für die Stadt und den früheren Amtsbezirk Durlach; Pfinztäler Bote für Grötzingen, Berghausen, Söllingen, Wöschbach u. Kleinsteinbach, Drittes Blatt',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Die deutsche Frau',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 10',
#        'Tägliches Verzeichnis der Neuerscheinungen',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der deutsche Motorsport',
#        'Der Landbote : Anzeiger für den Amtsbezirk Sinsheim und Umgebung, Beilage zum Landboten',
#        "Unterhaltungsblatt : Beilage zu den Zeitungen des E. Holterdorf'schen Verlages und der Beckumer Zeitung",
#        'Karlsruher Tagblatt, Landwirtschaft u. Gartenbau',
#        'Badische Wirtschaftszeitung : amtl. Organ d. Wirtschaftskammer Baden u.d. Badischen u. Elsässischen Industrie- und Handelskammern Mannheim, Karlsruhe, Pforzheim, Freiburg mit d. Bezirksstellen Schopfheim u. Konstanz, Strassburg, Mühlhausen (Elsass), Kolmar, zugl. Mitteilungen d. Amtlichen Getreide-Grossmarktes Karlsruhe',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der unbesiegte Soldat',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, [No.24] Sonntagausgabe',
#        'Der Volksfreund : Tageszeitung für das werktätige Volk Mittelbadens, Die Mußestunde',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, [No. 53] Die deutsche Frau',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, [No. 53]',
#        'Hallische Nachrichten : General-Anzeiger für Halle und die Provinz Sachsen, Frauenzeitung für die Provinz Sachsen Organ des Verbandes Hallischer Frauenvereine Beilage der Hallischen Nachrichten',
#        'Volksblatt <Halle, Saale> : Tageszeitung der Sozialdemokratischen Partei Deutschlands für die Provinz Sachsen, #',
#        'Hallische Nachrichten : General-Anzeiger für Halle und die Provinz Sachsen, Wahl-Ausgabe',
#        'Breckerfelder Zeitung. 1917-1933',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 13',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, [30.4. u. 1.5.1933] Sonntagausgabe',
#        'Badischer Beobachter : Hauptorgan der badischen Zentrumspartei, [Titelblatt fehlt]',
#        'Die Badische Lehrerin : Vereinsbl. d. Vereins Badischer Lehrer und Lehrerinnen',
#        'Karlsruher Tagblatt, Wintersport und Wandern',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine, Sonderdruck zur "Badischen Schulzeitung" Nr.4',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Extrablatt',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Karfreitagausgabe',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 5',
#        'Die Frau : Beilage zum Hannoverschen Kurier',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Dienstagausgabe',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 17',
#        'Karlsruher Tagblatt, Sonderbeilage. Glückwunsch-Anzeiger zum Jahreswechsel 1933',
#        'Der Pfeiferturm : Beiträge zur Heimatgeschichte und Volkskunde Brettens und seiner Umgebung',
#        'Mittelbadischer Courier : Ettlinger Tagblatt ; mit den neuesten Handels-Nachrichten für Stadt und Bezirk Ettlingen, Volksfreund Tageszeitung für das Werktätige Volk Mittelbadens',
#        'Riesaer Tageblatt und Anzeiger : (Elbeblatt und Anzeiger) : amtliche Bekanntmachungen für die Stadt und den Landkreis Riesa, 01-Sonderausgabe',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Ortenauer Volkswarte',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine, Sonderdruck zur "Badischen Schulzeitung" Nr.3',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 12',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Der Wissenschaftler',
#        'Jüdische Wohlfahrtspflege und Sozialpolitik',
#        'Karlsruher akademische Mitteilungen : amtliches Mitteilungsblatt der Technischen Hochschule Fridericiana',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 14',
#        'Rabenauer Anzeiger : Lokal- und Anzeigeblatt für Rabenau und Umg.',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Am badischen Herd',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Das Hanauerland',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine, Beilage zur Badischen Schulzeitung Nr.7',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Neujahrsausgabe',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, [u. ]',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Merkur-Rundschau',
#        'Jüdisches Gemeindeblatt für Mittelsachsen : Chemnitz, Annaberg, Zwickau, Plauen',
#        'Karlsruher Tagblatt, Technische Rundschau',
#        'Der Führer : das Hauptorgan der NSDAP Gau Baden; der badische Staatsanzeiger, Das Grüselhorn',
#        'Soziale Rundschau',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 15',
#        'Badische Schulzeitung : Vereinsbl. d. Badischen Lehrervereins u. Verkündigungsstelle d. Fürsorgevereine, Sonderdruck zur "Badischen Schulzeitung" Nr.5',
#        'Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden, Samstagausgabe',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 7',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 4',
#        'Der Ring. 1933-',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 11',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 1',
#        'Karlsruher Tagblatt, Sonderbeilage. 1. Mai. Der Tag der Arbeit',
#        'Karlsruher Tagblatt, Inhaltsverzeichnis des Jahrgangs 1933 der "Pyramide"',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 2',
#        'Karlsruher Tagblatt, Sonderbeilage. Gutes Licht - der beste Arbeitshelfer!',
#        'Karlsruher Tagblatt, Ostern',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 16',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 8',
#        'Börsenblatt für den deutschen Buchhandel : bbb ; Fachzeitschr. für Verlagswesen u. Buchhandel, 01-Titelblatt/Inhalt',
#        'Karlsruher Zeitung, Wissenschaft und Bildung Nr. 9',
#        'Hamburger Fremdenblatt, Abendausgabe'], dtype=object)

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead
import torch
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
model.to(device) 
model.eval()

def get_perplexity(text: str):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    input_ids = inputs["input_ids"].to(device) 
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
        loss = outputs.loss
    return torch.exp(loss).item()

Perplexity = pd.DataFrame(columns=["Text", "Perplexity"])
start_time = time.time() 
length = int(len(df_1933["plainpagefulltext"])*0.015) 
random_samples = df_1933["plainpagefulltext"].sample(n=length, random_state=42)
empty = 0
for i, t in enumerate(random_samples, 1): 
    #skip empty t
    if not t.strip():
        empty+=1
        continue
    perplexity_value = get_perplexity(t)
    #print(f"Text: {t}\nPerplexity: {perplexity_value:.2f}\n")
    
    new_row = {"Text": t, "Perplexity": perplexity_value}
    Perplexity = pd.concat([Perplexity, pd.DataFrame([new_row])], ignore_index=True)
    
    if i % 100 == 0:
        elapsed = time.time() - start_time
        remaining = len(random_samples) - i
        estimated_time = remaining * (elapsed/100) /60
        print(f"Processed {i} texts — Last 100 took {elapsed:.2f} seconds")
        print(f"{remaining} left, which will take approximately {estimated_time:.2f} min\n")
        start_time = time.time() 

print("Empty plainpagefulltext columns " + str(empty))
Perplexity.to_csv("Perplexity_1933.csv")
Perplexity["Perplexity"].mean()
# Out:
# c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\transformers\models\auto\modeling_auto.py:2020: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# C:\Users\finke\AppData\Local\Temp\ipykernel_4060\1450563105.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   Perplexity = pd.concat([Perplexity, pd.DataFrame([new_row])], ignore_index=True)
# Processed 100 texts — Last 100 took 41.41 seconds
# 1900 left, which will take approximately 13.11 min
#
# Processed 200 texts — Last 100 took 38.02 seconds
# 1800 left, which will take approximately 11.41 min
#
# Processed 300 texts — Last 100 took 38.11 seconds
# 1700 left, which will take approximately 10.80 min
#
# Processed 400 texts — Last 100 took 37.22 seconds
# 1600 left, which will take approximately 9.92 min
#
# Processed 500 texts — Last 100 took 37.89 seconds
# 1500 left, which will take approximately 9.47 min
#
# Processed 600 texts — Last 100 took 37.94 seconds
# 1400 left, which will take approximately 8.85 min
#
# Processed 700 texts — Last 100 took 38.51 seconds
# 1300 left, which will take approximately 8.34 min
#
# Processed 800 texts — Last 100 took 38.50 seconds
# 1200 left, which will take approximately 7.70 min
#
# Processed 900 texts — Last 100 took 37.65 seconds
# 1100 left, which will take approximately 6.90 min
#
# Processed 1000 texts — Last 100 took 37.99 seconds
# 1000 left, which will take approximately 6.33 min
#
# Processed 1100 texts — Last 100 took 38.51 seconds
# 900 left, which will take approximately 5.78 min
#
# Processed 1200 texts — Last 100 took 37.76 seconds
# 800 left, which will take approximately 5.04 min
#
# Processed 1300 texts — Last 100 took 38.25 seconds
# 700 left, which will take approximately 4.46 min
#
# Processed 1400 texts — Last 100 took 37.08 seconds
# 600 left, which will take approximately 3.71 min
#
# Processed 1500 texts — Last 100 took 37.60 seconds
# 500 left, which will take approximately 3.13 min
#
# Processed 1600 texts — Last 100 took 37.37 seconds
# 400 left, which will take approximately 2.49 min
#
# Processed 1700 texts — Last 100 took 37.63 seconds
# 300 left, which will take approximately 1.88 min
#
# Processed 1800 texts — Last 100 took 37.55 seconds
# 200 left, which will take approximately 1.25 min
#
# Processed 1900 texts — Last 100 took 37.64 seconds
# 100 left, which will take approximately 0.63 min
#
# Processed 2000 texts — Last 100 took 37.69 seconds
# 0 left, which will take approximately 0.00 min
#
# Empty plainpagefulltext columns 1
# np.float64(192.22110851542124)

# %% [markdown]
# ## 1980-1994

# %%
df_1980 = pd.read_pickle("./data_deutsches_zeitungsportal_misc/newspapers_ger_1980_part_1.pkl")  
#read_in_df = pd.read_parquet("./data_deutsches_zeitungsportal_misc/newspapers_ger_1933_part_1.pkl")  
df_1980
# Out:
#                                                 page_id  pagenumber  \
# 0     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_001_DDB_...           1
# 1     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_002_DDB_...           2
# 2     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_003_DDB_...           3
# 3     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_004_DDB_...           4
# 4     22BDAOGGUQML4XYWD424L5CQGBEPUOPC-alto_005_DDB_...           5
# ...                                                 ...         ...
# 2802  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_004_DDB_...           4
# 2803  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_005_DDB_...           5
# 2804  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_006_DDB_...           6
# 2805  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_007_DDB_...           7
# 2806  ZZUSBBUNDOSMBSOV6HZT4GBZKLMCUYOZ-alto_008_DDB_...           8
#
#                                             paper_title  \
# 0     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 1     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 3     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 4     Der Motor : Zeitung der Dieselmotorenwerk Rost...
# ...                                                 ...
# 2802  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2803  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2804  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2805  Der Motor : Zeitung der Dieselmotorenwerk Rost...
# 2806  Der Motor : Zeitung der Dieselmotorenwerk Rost...
#
#                        provider_ddb_id                    provider     zdb_id  \
# 0     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 1     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 3     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 4     UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# ...                                ...                         ...        ...
# 2802  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2803  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2804  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2805  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
# 2806  UPHR66ECKLOQBHTW23IVD2SE4UBEF2XY  Schifffahrtsmuseum Rostock  3139118-7
#
#         publication_date place_of_distribution language  \
# 0    1980-03-11 12:00:00             [Rostock]    [ger]
# 1    1980-03-11 12:00:00             [Rostock]    [ger]
# 2    1980-03-11 12:00:00             [Rostock]    [ger]
# 3    1980-03-11 12:00:00             [Rostock]    [ger]
# 4    1980-03-11 12:00:00             [Rostock]    [ger]
# ...                  ...                   ...      ...
# 2802 1981-10-13 12:00:00             [Rostock]    [ger]
# 2803 1981-10-13 12:00:00             [Rostock]    [ger]
# 2804 1981-10-13 12:00:00             [Rostock]    [ger]
# 2805 1981-10-13 12:00:00             [Rostock]    [ger]
# 2806 1981-10-13 12:00:00             [Rostock]    [ger]
#
#                                  thumbnail  \
# 0     3c17273a-1495-4345-8bf5-df324f159dce
# 1     3c17273a-1495-4345-8bf5-df324f159dce
# 2     3c17273a-1495-4345-8bf5-df324f159dce
# 3     3c17273a-1495-4345-8bf5-df324f159dce
# 4     3c17273a-1495-4345-8bf5-df324f159dce
# ...                                    ...
# 2802  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2803  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2804  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2805  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
# 2806  f82d7cb1-5606-43c2-a43b-4db2c85ddf15
#
#                                            pagefulltext  \
# 0     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 1     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 2     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 3     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# 4     [/data/altos/22/BD/22BDAOGGUQML4XYWD424L5CQGBE...
# ...                                                 ...
# 2802  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2803  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2804  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2805  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
# 2806  [/data/altos/ZZ/US/ZZUSBBUNDOSMBSOV6HZT4GBZKLM...
#
#                    pagename  \
# 0     alto_001_DDB_FULLTEXT
# 1     alto_002_DDB_FULLTEXT
# 2     alto_003_DDB_FULLTEXT
# 3     alto_004_DDB_FULLTEXT
# 4     alto_005_DDB_FULLTEXT
# ...                     ...
# 2802  alto_004_DDB_FULLTEXT
# 2803  alto_005_DDB_FULLTEXT
# 2804  alto_006_DDB_FULLTEXT
# 2805  alto_007_DDB_FULLTEXT
# 2806  alto_008_DDB_FULLTEXT
#
#                                       preview_reference  \
# 0     https://api.deutsche-digitale-bibliothek.de/bi...
# 1     https://api.deutsche-digitale-bibliothek.de/bi...
# 2     https://api.deutsche-digitale-bibliothek.de/bi...
# 3     https://api.deutsche-digitale-bibliothek.de/bi...
# 4     https://api.deutsche-digitale-bibliothek.de/bi...
# ...                                                 ...
# 2802  https://api.deutsche-digitale-bibliothek.de/bi...
# 2803  https://api.deutsche-digitale-bibliothek.de/bi...
# 2804  https://api.deutsche-digitale-bibliothek.de/bi...
# 2805  https://api.deutsche-digitale-bibliothek.de/bi...
# 2806  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                       plainpagefulltext
# 0     = Organ der Parteileitung der SED im VEB Diese...
# 1     Am Arbeitsplatz mehr Vorsicht! 25 betriebliche...
# 2     Einer kennt ihn als Vertrauensmann, den Jugend...
# 3     der KDT und URANIA im DMR „MOTOR“ Leserausspra...
# 4     At ontage) heißt es so zügiger kann der a scho...
# ...                                                 ...
# 2802  |Ehrentafel Anlaßlich des 32, Jahrestages DDR ...
# 2803  icheren Händen ısatz und Disziplin ausgezeichn...
# 2804  SE NETTE ET TEE | | GELOBNIS % Wir, junge Bürg...
# 2805  port Am 28.September standen sich auf dem Lok-...
# 2806  Allerlei bunt gemischt Am Bildschirm miterlebe...
#
# [2807 rows x 14 columns]

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead
import torch
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
model.to(device) 
model.eval()

def get_perplexity(text: str):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    input_ids = inputs["input_ids"].to(device) 
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
        loss = outputs.loss
    return torch.exp(loss).item()

Perplexity = pd.DataFrame(columns=["Text", "Perplexity"])
start_time = time.time() 
length = int(len(df_1980["plainpagefulltext"])*0.2) 
random_samples = df_1980["plainpagefulltext"].sample(n=length, random_state=42)
empty = 0
for i, t in enumerate(random_samples, 1): 
    #skip empty t
    if not t.strip():
        empty+=1
        continue
    perplexity_value = get_perplexity(t)
    #print(f"Text: {t}\nPerplexity: {perplexity_value:.2f}\n")
    
    new_row = {"Text": t, "Perplexity": perplexity_value}
    Perplexity = pd.concat([Perplexity, pd.DataFrame([new_row])], ignore_index=True)
    
    if i % 100 == 0:
        elapsed = time.time() - start_time
        remaining = len(random_samples) - i
        estimated_time = remaining * (elapsed/100) /60
        print(f"Processed {i} texts — Last 100 took {elapsed:.2f} seconds")
        print(f"{remaining} left, which will take approximately {estimated_time:.2f} min\n")
        start_time = time.time() 

print("Empty plainpagefulltext columns " + str(empty))
Perplexity.to_csv("Perplexity_1980.csv")
Perplexity["Perplexity"].mean()
# Out:
# c:\Users\finke\PycharmProjects\Data Stories Visual\.venv\lib\site-packages\transformers\models\auto\modeling_auto.py:2020: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# C:\Users\finke\AppData\Local\Temp\ipykernel_4060\476636950.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   Perplexity = pd.concat([Perplexity, pd.DataFrame([new_row])], ignore_index=True)
# Processed 100 texts — Last 100 took 36.80 seconds
# 461 left, which will take approximately 2.83 min
#
# Processed 200 texts — Last 100 took 36.88 seconds
# 361 left, which will take approximately 2.22 min
#
# Processed 300 texts — Last 100 took 37.06 seconds
# 261 left, which will take approximately 1.61 min
#
# Processed 400 texts — Last 100 took 36.86 seconds
# 161 left, which will take approximately 0.99 min
#
# Processed 500 texts — Last 100 took 36.98 seconds
# 61 left, which will take approximately 0.38 min
#
# Empty plainpagefulltext columns 0
# np.float64(132.82616769991245)

# %% [markdown]
# # Comparing Perplexity

# %%
Perplexity_1933 = pd.read_csv('Perplexity_1933.csv')
Perplexity_1980 = pd.read_csv('Perplexity_1980.csv')

# %%
print("Mean 1933: " + str(Perplexity_1933["Perplexity"].mean()))
print("Mean 1980: " + str(Perplexity_1980["Perplexity"].mean()))
print(f"_____________________________________________________")
print("Median 1933: " + str(Perplexity_1933["Perplexity"].median()))
print("Median 1980: " + str(Perplexity_1980["Perplexity"].median()))
# Out:
# Mean 1933: 192.22110851542124
# Mean 1980: 132.82616769991245
# _____________________________________________________
# Median 1933: 156.34481811523438
# Median 1980: 126.85960388183594
